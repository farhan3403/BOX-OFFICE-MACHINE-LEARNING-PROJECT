# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df = pd.read_csv('train.csv',header=-1)
df.head()
# Out:
#    0                                                  1         2   \
# 0  id                              belongs_to_collection    budget
# 1   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 2   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 3   3                                                NaN   3300000
# 4   4                                                NaN   1200000
#
#                                                   3   \
# 0                                             genres
# 1                     [{'id': 35, 'name': 'Comedy'}]
# 2  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 3                      [{'id': 18, 'name': 'Drama'}]
# 4  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
#
#                                   4          5                  6   \
# 0                           homepage    imdb_id  original_language
# 1                                NaN  tt2637294                 en
# ...

# %%
df.describe()
# Out:
#           0                                                  1     2   \
# count   3001                                                605  3001
# unique  3001                                                423   407
# top      904  [{'id': 645, 'name': 'James Bond Collection', ...     0
# freq       1                                                 16   812
#
#                                    3                                  4   \
# count                            2994                                947
# unique                            873                                942
# top     [{'id': 18, 'name': 'Drama'}]  http://www.transformersmovie.com/
# freq                              266                                  4
#
#                5     6       7   \
# count        3001  3001    3001
# unique       3001    37    2976
# top     tt0116322    en  Joshua
# freq            1  2575       2
#
# ...

# %%
col_name=['ID','BELONGS_TO_COLLECTION','BUDGET','GENRES','HOMEPAGE','IMDB_ID','ORIGINAL_LANGUAGE','ORIGINAL_TITLE','OVERVIEW','POPULARITY','POSTER_PATH','PRODUCTION_COMPANIES','PRODUCTION_COUNTRIES','RELEASE_DATE','RUNTIME','SPOKEN_LANGUAGES','STATUS','TAGLINE','TITLE','KEYWORDS','CAST','CREW','REVENUE']

# %%
df.columns=col_name
df.head()
# Out:
#    ID                              BELONGS_TO_COLLECTION    BUDGET  \
# 0  id                              belongs_to_collection    budget
# 1   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 2   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 3   3                                                NaN   3300000
# 4   4                                                NaN   1200000
#
#                                               GENRES  \
# 0                                             genres
# 1                     [{'id': 35, 'name': 'Comedy'}]
# 2  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 3                      [{'id': 18, 'name': 'Drama'}]
# 4  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
#
#                             HOMEPAGE    IMDB_ID  ORIGINAL_LANGUAGE  \
# 0                           homepage    imdb_id  original_language
# 1                                NaN  tt2637294                 en
# ...

# %%
df.describe()
# Out:
#           ID                              BELONGS_TO_COLLECTION BUDGET  \
# count   3001                                                605   3001
# unique  3001                                                423    407
# top      904  [{'id': 645, 'name': 'James Bond Collection', ...      0
# freq       1                                                 16    812
#
#                                GENRES                           HOMEPAGE  \
# count                            2994                                947
# unique                            873                                942
# top     [{'id': 18, 'name': 'Drama'}]  http://www.transformersmovie.com/
# freq                              266                                  4
#
#           IMDB_ID ORIGINAL_LANGUAGE ORIGINAL_TITLE  \
# count        3001              3001           3001
# unique       3001                37           2976
# top     tt0116322                en         Joshua
# ...
